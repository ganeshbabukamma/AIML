# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Check versions
print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)
print("matplotlib version:", plt.matplotlib.__version__)
print("seaborn version:", sns.__version__)
# Out:
# numpy version: 2.0.2
# pandas version: 2.2.2
# matplotlib version: 3.10.0
# seaborn version: 0.13.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab

# %%
df = pd.read_parquet('2023-1.parquet')
sampled_data = df.sample(frac = 0.05 ,random_state = 42)
#sampled_data.info()
df = pd.read_parquet('2023-2.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-3.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-4.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-5.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-6.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-7.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-8.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-9.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-10.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-11.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
#sampled_data.info()
df = pd.read_parquet('2023-12.parquet')
df1= df.sample(frac = 0.05 ,random_state = 42)
sampled_data = pd.concat([sampled_data, df1])
sampled_data.info()
sampled_data.to_parquet('2023_sample.parquet')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1896427 entries, 323412 to 1516501
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  Airport_fee            float64
# dtypes: datetime64[us](2), float64(13), int64(4), object(1)
# memory usage: 303.8+ MB

# %%
import os
#print(os.name)
#Print current working directory
print("Current directory:" , os.getcwd())
# Create a list of all the twelve files to read
file_list = os.listdir()
#print(os.listdir())
# initialise an empty dataframe
df = pd.DataFrame()
#df.info()
sampled_data = pd.DataFrame()
#sampled_data.info()
from datetime import datetime
for file_name in file_list:
    try:
        # file path for the current file
        file_path = os.path.join(os.getcwd(), file_name)
        print(file_path)
        df = pd.read_parquet(file_path)


        #df1 = df.sample(frac = 0.05 ,random_state = 42)
        df1 = df.sample(n=30000,random_state = 42)
        sampled_data = pd.concat([sampled_data, df1])
        #sampled_data.info()
    except Exception as e:
        print(f"Error reading file {file_name}: {e}")

sampled_data.info()
sampled_data.to_parquet('2023_sample.parquet')
# Out:
# Current directory: /content/drive/MyDrive/Colab
# /content/drive/MyDrive/Colab/2023-9.parquet
# /content/drive/MyDrive/Colab/2023-5.parquet
# /content/drive/MyDrive/Colab/2023-6.parquet
# /content/drive/MyDrive/Colab/2023-2.parquet
# /content/drive/MyDrive/Colab/2023-8.parquet
# /content/drive/MyDrive/Colab/2023-7.parquet
# /content/drive/MyDrive/Colab/2023-10.parquet
# /content/drive/MyDrive/Colab/2023-3.parquet
# /content/drive/MyDrive/Colab/2023-12.parquet
# /content/drive/MyDrive/Colab/2023-4.parquet
# /content/drive/MyDrive/Colab/taxi_zones.dbf
# Error reading file taxi_zones.dbf: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/taxi_zones.shp.xml
# Error reading file taxi_zones.shp.xml: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/taxi_zones.shp
# Error reading file taxi_zones.shp: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/taxi_zones.sbn
# Error reading file taxi_zones.sbn: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/taxi_zones.sbx
# Error reading file taxi_zones.sbx: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/taxi_zones.prj
# Error reading file taxi_zones.prj: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/2023-11.parquet
# /content/drive/MyDrive/Colab/taxi_zones.shx
# Error reading file taxi_zones.shx: Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# /content/drive/MyDrive/Colab/2023-1.parquet
# /content/drive/MyDrive/Colab/2023_sample.parquet
# <class 'pandas.core.frame.DataFrame'>
# Index: 390000 entries, 2603400 to 739542
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               390000 non-null  int64
#  1   tpep_pickup_datetime   390000 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  390000 non-null  datetime64[us]
#  3   passenger_count        376760 non-null  float64
#  4   trip_distance          390000 non-null  float64
#  5   RatecodeID             376760 non-null  float64
#  6   store_and_fwd_flag     376760 non-null  object
#  7   PULocationID           390000 non-null  int64
#  8   DOLocationID           390000 non-null  int64
#  9   payment_type           390000 non-null  int64
#  10  fare_amount            390000 non-null  float64
#  11  extra                  390000 non-null  float64
#  12  mta_tax                390000 non-null  float64
#  13  tip_amount             390000 non-null  float64
#  14  tolls_amount           390000 non-null  float64
#  15  improvement_surcharge  390000 non-null  float64
#  16  total_amount           390000 non-null  float64
#  17  congestion_surcharge   376760 non-null  float64
#  18  Airport_fee            345125 non-null  float64
#  19  airport_fee            31635 non-null   float64
# dtypes: datetime64[us](2), float64(13), int64(4), object(1)
# memory usage: 62.5+ MB

# %%
df = pd.read_parquet('2023_sample.parquet')
df.head()
#df.info()
df.reset_index(inplace=True)
df.head()
del df['index']
df.head()
df['airport_fee'] = df['airport_fee'].fillna(0)
df['Airport_fee'] = df['Airport_fee'].fillna(0)
df['Airport_Fees_Combined'] = df['airport_fee'] + df['Airport_fee']
del df['airport_fee']
del df['Airport_fee']
df.head()

df['store_and_fwd_flag'].info()
def find_columns_with_negative_values(df):
    negative_value_columns = []
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
          if (df[col] < 0).any():
            negative_value_columns.append(col)
    return negative_value_columns

columns_with_negatives = find_columns_with_negative_values(df)
#print(columns_with_negatives)
df['extra'] = df['extra'].mask(df['extra'] < 0).fillna(0)
df['mta_tax'] = df['mta_tax'].mask(df['mta_tax'] < 0).fillna(0)
df['improvement_surcharge'] = df['improvement_surcharge'].mask(df['improvement_surcharge'] < 0).fillna(0)
df['total_amount'] = df['total_amount'].mask(df['total_amount'] < 0).fillna(0)
df['congestion_surcharge'] = df['congestion_surcharge'].mask(df['congestion_surcharge'] < 0).fillna(0)
df['Airport_Fees_Combined'] = df['Airport_Fees_Combined'].mask(df['Airport_Fees_Combined'] < 0).fillna(0)
columns_with_negatives = find_columns_with_negative_values(df)
print(columns_with_negatives)
df.head()
(df['passenger_count'].isna()).sum()
(df['total_amount'].isna()).sum()
nan_count = df.isna().sum()
print("Count NaN values of column wise:\n", nan_count)
percentage_nan=(df.isna().sum() / len(df)) * 100
print("percentage_nan:\n", percentage_nan)
nan_count = df.isna().sum(axis = 1)
print("Count NaN values of all rows:\n", nan_count)
df.loc[:, df.isna().any()]
print("NAN of passenger count", (df['passenger_count'].isna()).sum())
median_value = df['passenger_count'].median()
print("median_value:\n", median_value)
df['passenger_count'] = df['passenger_count'].fillna(median_value)
print("NAN of passenger count", (df['passenger_count'].isna()).sum())
np.count_nonzero(df['passenger_count']==0)
print("zero passenger count", np.count_nonzero(df['passenger_count']==0))
df['passenger_count']= np.where(df['passenger_count']==0, median_value, df['passenger_count'])
np.count_nonzero(df['passenger_count']==0)
print("zero passenger count", np.count_nonzero(df['passenger_count']==0))

print("NAN of RatecodeID count", (df['RatecodeID'].isna()).sum())
median_value = df['RatecodeID'].median()
print("median_value:\n", median_value)
df['RatecodeID'] = df['RatecodeID'].fillna(median_value)
print("NAN of RatecodeID count", (df['RatecodeID'].isna()).sum())

print("NAN of congestion_surcharge count", (df['congestion_surcharge'].isna()).sum())


nan_count = df.isna().sum()
print("Count NaN values of column wise:\n", nan_count)

print("NAN of store_and_fwd_flag count", (df['store_and_fwd_flag'].isna()).sum())

df['store_and_fwd_flag'] = df['store_and_fwd_flag'].fillna('N')
print("NAN of store_and_fwd_flag  count", (df['store_and_fwd_flag'].isna()).sum())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 390000 entries, 0 to 389999
# Series name: store_and_fwd_flag
# Non-Null Count   Dtype
# --------------   -----
# 376760 non-null  object
# dtypes: object(1)
# memory usage: 3.0+ MB
# []
# Count NaN values of column wise:
#  VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          13240
# trip_distance                0
# RatecodeID               13240
# store_and_fwd_flag       13240
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# Airport_Fees_Combined        0
# dtype: int64
# percentage_nan:
#  VendorID                 0.000000
# tpep_pickup_datetime     0.000000
# tpep_dropoff_datetime    0.000000
# passenger_count          3.394872
# trip_distance            0.000000
# RatecodeID               3.394872
# store_and_fwd_flag       3.394872
# PULocationID             0.000000
# DOLocationID             0.000000
# payment_type             0.000000
# fare_amount              0.000000
# extra                    0.000000
# mta_tax                  0.000000
# tip_amount               0.000000
# tolls_amount             0.000000
# improvement_surcharge    0.000000
# total_amount             0.000000
# congestion_surcharge     0.000000
# Airport_Fees_Combined    0.000000
# dtype: float64
# Count NaN values of all rows:
#  0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 389995    0
# 389996    0
# 389997    0
# 389998    0
# 389999    0
# Length: 390000, dtype: int64
# NAN of passenger count 13240
# median_value:
#  1.0
# NAN of passenger count 0
# zero passenger count 5968
# zero passenger count 0
# NAN of RatecodeID count 13240
# median_value:
#  1.0
# NAN of RatecodeID count 0
# NAN of congestion_surcharge count 0
# Count NaN values of column wise:
#  VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count              0
# trip_distance                0
# RatecodeID                   0
# store_and_fwd_flag       13240
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# Airport_Fees_Combined        0
# dtype: int64
# NAN of store_and_fwd_flag count 13240
# NAN of store_and_fwd_flag  count 0

# %%
df.describe()
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  390000.000000                      390000                      390000
# mean        1.737823  2023-07-01 17:57:24.276023  2023-07-01 18:14:53.760141
# min         1.000000         2009-01-01 04:36:53         2009-01-02 00:00:00
# 25%         1.000000  2023-04-01 03:14:56.500000  2023-04-01 03:22:47.750000
# 50%         2.000000  2023-06-30 19:07:32.500000  2023-06-30 19:28:30.500000
# 75%         2.000000  2023-10-01 15:14:30.250000  2023-10-01 15:41:28.750000
# max         6.000000         2023-12-31 23:53:29         2024-01-01 01:59:13
# std         0.444920                         NaN                         NaN
#
#        passenger_count  trip_distance     RatecodeID   PULocationID  \
# count    390000.000000  390000.000000  390000.000000  390000.000000
# mean          1.374082       3.908600       1.610190     165.180938
# min           1.000000       0.000000       1.000000       1.000000
# 25%           1.000000       1.050000       1.000000     132.000000
# 50%           1.000000       1.790000       1.000000     162.000000
# 75%           1.000000       3.400000       1.000000     234.000000
# max           8.000000   78099.980000      99.000000     265.000000
# std           0.868806     155.261889       7.237939      63.954326
#
#         DOLocationID   payment_type    fare_amount          extra  \
# count  390000.000000  390000.000000  390000.000000  390000.000000
# mean      163.854954       1.164141      19.874896       1.578126
# min         1.000000       0.000000       0.000000       0.000000
# 25%       113.000000       1.000000       9.300000       0.000000
# 50%       162.000000       1.000000      13.500000       1.000000
# 75%       234.000000       1.000000      21.900000       2.500000
# max       265.000000       4.000000     900.000000      14.250000
# std        69.800755       0.508738      18.374529       1.828165
#
#              mta_tax     tip_amount   tolls_amount  improvement_surcharge  \
# count  390000.000000  390000.000000  390000.000000          390000.000000
# mean        0.495252       3.557174       0.601212               0.999128
# min         0.000000       0.000000       0.000000               0.000000
# 25%         0.500000       1.000000       0.000000               1.000000
# 50%         0.500000       2.850000       0.000000               1.000000
# 75%         0.500000       4.420000       0.000000               1.000000
# max         0.800000     300.000000     132.040000               1.000000
# std         0.048555       4.100514       2.186005               0.027186
#
#         total_amount  congestion_surcharge  Airport_Fees_Combined
# count  390000.000000         390000.000000          390000.000000
# mean       28.957117              2.230667               0.139638
# min         0.000000              0.000000               0.000000
# 25%        15.960000              2.500000               0.000000
# 50%        21.000000              2.500000               0.000000
# 75%        30.940000              2.500000               0.000000
# max       901.000000              2.500000               1.750000
# std        22.949518              0.775109               0.460096

# %%
df = df[df.trip_distance <= 250]
df.describe()
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  389995.000000                      389995                      389995
# mean        1.737822  2023-07-01 17:57:55.166194  2023-07-01 18:15:24.645531
# min         1.000000         2009-01-01 04:36:53         2009-01-02 00:00:00
# 25%         1.000000         2023-04-01 03:14:28  2023-04-01 03:22:03.500000
# 50%         2.000000         2023-06-30 19:07:29         2023-06-30 19:28:22
# 75%         2.000000  2023-10-01 15:16:05.500000  2023-10-01 15:44:08.500000
# max         6.000000         2023-12-31 23:53:29         2024-01-01 01:59:13
# std         0.444920                         NaN                         NaN
#
#        passenger_count  trip_distance     RatecodeID   PULocationID  \
# count    389995.000000  389995.000000  389995.000000  389995.000000
# mean          1.374087       3.456387       1.609946     165.180438
# min           1.000000       0.000000       1.000000       1.000000
# 25%           1.000000       1.050000       1.000000     132.000000
# 50%           1.000000       1.790000       1.000000     162.000000
# 75%           1.000000       3.400000       1.000000     234.000000
# max           8.000000     170.300000      99.000000     265.000000
# std           0.868810       4.559161       7.236305      63.954091
#
#         DOLocationID   payment_type    fare_amount          extra  \
# count  389995.000000  389995.000000  389995.000000  389995.000000
# mean      163.855201       1.164153      19.874848       1.578146
# min         1.000000       0.000000       0.000000       0.000000
# 25%       113.000000       1.000000       9.300000       0.000000
# 50%       162.000000       1.000000      13.500000       1.000000
# 75%       234.000000       1.000000      21.900000       2.500000
# max       265.000000       4.000000     900.000000      14.250000
# std        69.800716       0.508728      18.374638       1.828168
#
#              mta_tax     tip_amount   tolls_amount  improvement_surcharge  \
# count  389995.000000  389995.000000  389995.000000          389995.000000
# mean        0.495252       3.557175       0.601202               0.999128
# min         0.000000       0.000000       0.000000               0.000000
# 25%         0.500000       1.000000       0.000000               1.000000
# 50%         0.500000       2.850000       0.000000               1.000000
# 75%         0.500000       4.420000       0.000000               1.000000
# max         0.800000     300.000000     132.040000               1.000000
# std         0.048556       4.100527       2.185995               0.027186
#
#         total_amount  congestion_surcharge  Airport_Fees_Combined
# count  389995.000000         389995.000000          389995.000000
# mean       28.957078              2.230695               0.139640
# min         0.000000              0.000000               0.000000
# 25%        15.960000              2.500000               0.000000
# 50%        21.000000              2.500000               0.000000
# 75%        30.940000              2.500000               0.000000
# max       901.000000              2.500000               1.750000
# std        22.949643              0.775073               0.460099

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'Airport_Fees_Combined']

# %%
df['fare_amount'].describe()
# Out:
# count    389995.000000
# mean         19.874848
# std          18.374638
# min           0.000000
# 25%           9.300000
# 50%          13.500000
# 75%          21.900000
# max         900.000000
# Name: fare_amount, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30))
plt.show()

# %%
df['VendorID'].value_counts()
# Out:
# VendorID
# 2    287307
# 1    102600
# 6        88
# Name: count, dtype: int64

# %%
df['VendorID'].describe()
df = df[df.VendorID <= 2]
df['VendorID'].describe()
# Out:
# count    389907.000000
# mean          1.736860
# std           0.440338
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           2.000000
# max           2.000000
# Name: VendorID, dtype: float64

# %%
df['passenger_count'].value_counts()
# Out:
# passenger_count
# 1.0    302450
# 2.0     57046
# 3.0     14101
# 4.0      7949
# 5.0      5012
# 6.0      3347
# 8.0         2
# Name: count, dtype: int64

# %%
df = df[df.passenger_count <= 6]
df['passenger_count'].describe()
# Out:
# count    389905.000000
# mean          1.374137
# std           0.868763
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           6.000000
# Name: passenger_count, dtype: float64

# %%
df['trip_distance'].value_counts()
df['trip_distance'].describe()
# Out:
# count    389905.000000
# mean          3.454809
# std           4.557774
# min           0.000000
# 25%           1.050000
# 50%           1.790000
# 75%           3.400000
# max         170.300000
# Name: trip_distance, dtype: float64

# %%
df = df[df.trip_distance >0]
df['trip_distance'].describe()
df['trip_distance'].value_counts()
# Out:
# trip_distance
# 0.90     5299
# 1.00     5175
# 1.10     5103
# 0.80     5024
# 1.20     4995
#          ...
# 26.32       1
# 40.95       1
# 40.10       1
# 62.75       1
# 28.57       1
# Name: count, Length: 3072, dtype: int64

# %%
df.describe()
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  382285.000000                      382285                      382285
# mean        1.743657  2023-07-01 01:21:42.137719  2023-07-01 01:39:16.872153
# min         1.000000         2009-01-01 04:36:53         2009-01-02 00:00:00
# 25%         1.000000         2023-03-31 17:55:26         2023-03-31 18:11:57
# 50%         2.000000         2023-06-29 13:57:12         2023-06-29 14:21:32
# 75%         2.000000         2023-09-30 18:33:31         2023-09-30 18:55:03
# max         2.000000         2023-12-31 23:53:29         2024-01-01 01:59:13
# std         0.436614                         NaN                         NaN
#
#        passenger_count  trip_distance     RatecodeID   PULocationID  \
# count    382285.000000  382285.000000  382285.000000  382285.000000
# mean          1.377415       3.523673       1.549339     165.232539
# min           1.000000       0.010000       1.000000       1.000000
# 25%           1.000000       1.100000       1.000000     132.000000
# 50%           1.000000       1.810000       1.000000     162.000000
# 75%           1.000000       3.480000       1.000000     234.000000
# max           6.000000     170.300000      99.000000     265.000000
# std           0.872093       4.576540       6.898931      63.798964
#
#         DOLocationID   payment_type    fare_amount          extra  \
# count  382285.000000  382285.000000  382285.000000  382285.000000
# mean      163.897346       1.167728      19.747886       1.598875
# min         1.000000       0.000000       0.000000       0.000000
# 25%       113.000000       1.000000       9.300000       0.000000
# 50%       162.000000       1.000000      13.500000       1.000000
# 75%       234.000000       1.000000      21.900000       2.500000
# max       265.000000       4.000000     750.000000      14.250000
# std        69.749646       0.490541      17.937167       1.831616
#
#              mta_tax     tip_amount   tolls_amount  improvement_surcharge  \
# count  382285.000000  382285.000000  382285.000000          382285.000000
# mean        0.496671       3.589228       0.603686               0.999606
# min         0.000000       0.000000       0.000000               0.000000
# 25%         0.500000       1.000000       0.000000               1.000000
# 50%         0.500000       2.880000       0.000000               1.000000
# 75%         0.500000       4.470000       0.000000               1.000000
# max         0.800000     300.000000      64.750000               1.000000
# std         0.040741       4.062043       2.175973               0.017561
#
#         total_amount  congestion_surcharge  Airport_Fees_Combined
# count  382285.000000         382285.000000          382285.000000
# mean       28.892807              2.261081               0.140591
# min         0.000000              0.000000               0.000000
# 25%        15.960000              2.500000               0.000000
# 50%        21.000000              2.500000               0.000000
# 75%        30.800000              2.500000               0.000000
# max       757.940000              2.500000               1.750000
# std        22.619719              0.734994               0.461513

# %%
df = df[df.payment_type >0]
df['payment_type'].value_counts()
df.describe()
# Out:
#             VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  372142.000000                      372142                      372142
# mean        1.742837  2023-06-30 18:44:00.752170  2023-06-30 19:01:31.869167
# min         1.000000         2009-01-01 04:36:53         2009-01-02 00:00:00
# 25%         1.000000         2023-03-31 13:05:01  2023-03-31 13:20:47.250000
# 50%         2.000000  2023-06-29 08:56:56.500000  2023-06-29 09:14:18.500000
# 75%         2.000000  2023-09-30 15:40:10.250000  2023-09-30 15:54:56.250000
# max         2.000000         2023-12-31 23:53:29         2024-01-01 01:59:13
# std         0.437070                         NaN                         NaN
#
#        passenger_count  trip_distance     RatecodeID   PULocationID  \
# count    372142.000000  372142.000000  372142.000000  372142.000000
# mean          1.387701       3.500053       1.564311     165.360250
# min           1.000000       0.010000       1.000000       1.000000
# 25%           1.000000       1.080000       1.000000     132.000000
# 50%           1.000000       1.800000       1.000000     162.000000
# 75%           1.000000       3.400000       1.000000     234.000000
# max           6.000000     170.300000      99.000000     265.000000
# std           0.881639       4.583355       6.991713      63.557056
#
#         DOLocationID   payment_type    fare_amount          extra  \
# count  372142.000000  372142.000000  372142.000000  372142.000000
# mean      164.097640       1.199556      19.663514       1.636444
# min         1.000000       1.000000       0.000000       0.000000
# 25%       114.000000       1.000000       9.300000       0.000000
# 50%       162.000000       1.000000      13.500000       1.000000
# 75%       234.000000       1.000000      21.900000       2.500000
# max       265.000000       4.000000     750.000000      14.250000
# std        69.695203       0.457177      18.006484       1.836664
#
#              mta_tax     tip_amount   tolls_amount  improvement_surcharge  \
# count  372142.000000  372142.000000  372142.000000          372142.000000
# mean        0.496714       3.589751       0.599068               0.999612
# min         0.000000       0.000000       0.000000               0.000000
# 25%         0.500000       1.000000       0.000000               1.000000
# 50%         0.500000       2.860000       0.000000               1.000000
# 75%         0.500000       4.450000       0.000000               1.000000
# max         0.800000     300.000000      60.000000               1.000000
# std         0.040478       4.075419       2.164483               0.017422
#
#         total_amount  congestion_surcharge  Airport_Fees_Combined
# count  372142.000000         372142.000000          372142.000000
# mean       28.830399              2.322709               0.144423
# min         0.000000              0.000000               0.000000
# 25%        15.960000              2.500000               0.000000
# 50%        21.000000              2.500000               0.000000
# 75%        30.600000              2.500000               0.000000
# max       757.940000              2.500000               1.750000
# std        22.712639              0.641714               0.467168

# %%
df['fare_amount'].value_counts(sort=True)
(df['fare_amount'] == 0).sum().sum()
df = df[df.fare_amount >0]
df['fare_amount'].value_counts()
df['fare_amount'].describe()
# Out:
# count    372084.000000
# mean         19.666579
# std          18.006214
# min           0.010000
# 25%           9.300000
# 50%          13.500000
# 75%          21.900000
# max         750.000000
# Name: fare_amount, dtype: float64

# %%
((df['fare_amount'] >200) & (df['trip_distance']<50)).sum().sum()
# Out:
# np.int64(81)

# %%
(df['fare_amount'] >300).sum().sum()
df[df["fare_amount"] >300]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 5522           1  2023-09-08 03:05:33   2023-09-08 03:25:54              1.0
# 6461           2  2023-09-29 23:20:34   2023-09-30 00:33:48              1.0
# 10742          1  2023-09-07 15:35:37   2023-09-07 18:13:37              1.0
# 66884          2  2023-04-02 15:34:36   2023-04-02 16:47:02              1.0
# 83735          2  2023-04-21 16:41:13   2023-04-21 18:32:12              1.0
# 100970         2  2023-03-04 14:14:08   2023-03-04 16:18:48              3.0
# 112638         2  2023-03-13 22:19:39   2023-03-14 00:08:02              6.0
# 135263         2  2023-07-24 12:07:14   2023-07-24 14:01:48              1.0
# 137659         2  2023-07-10 12:46:15   2023-07-10 13:59:31              1.0
# 147293         2  2023-07-28 21:48:12   2023-07-28 23:16:06              1.0
# 164754         2  2023-05-16 15:35:26   2023-05-16 16:53:33              1.0
# 238707         2  2023-06-17 14:24:30   2023-06-17 15:02:53              4.0
# 276145         2  2023-08-15 23:02:48   2023-08-16 00:56:10              1.0
# 284905         2  2023-08-07 20:47:10   2023-08-07 22:19:07              1.0
# 300448         2  2023-11-21 20:57:15   2023-11-22 00:02:28              1.0
# 312414         2  2023-11-25 17:39:25   2023-11-25 20:56:43              2.0
# 325364         1  2023-11-21 13:35:35   2023-11-21 15:28:40              4.0
# 326618         2  2023-11-18 18:37:35   2023-11-18 19:56:06              2.0
# 348204         2  2023-01-07 14:01:46   2023-01-07 16:46:54              1.0
# 365510         2  2023-06-20 15:35:13   2023-06-20 17:30:01              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 5522             8.20         5.0                  N           229
# 6461            59.60         4.0                  N           138
# 10742          105.00         5.0                  N           132
# 66884           48.56         4.0                  N           132
# 83735           48.25         4.0                  N           138
# 100970          82.80         4.0                  N           132
# 112638          73.07         4.0                  N           138
# 135263          60.58         5.0                  N           132
# 137659          44.23         4.0                  N            13
# 147293          89.15         5.0                  N           138
# 164754          44.36         5.0                  N           265
# 238707           5.12         5.0                  N           231
# 276145          97.69         5.0                  N           138
# 284905          61.46         5.0                  N           132
# 300448          62.75         4.0                  N           186
# 312414         170.30         5.0                  N           264
# 325364          60.50         5.0                  N           132
# 326618          52.49         4.0                  N           132
# 348204         147.83         1.0                  N           265
# 365510          58.61         5.0                  N           132
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 5522             126             3       750.00   0.00      0.0        0.00
# 6461             265             1       350.90   6.00      0.5       73.07
# 10742            265             2       500.00   0.00      0.0        0.00
# 66884            265             1       322.90   0.00      0.5        0.00
# 83735            265             1       314.50   7.50      0.5       80.88
# 100970           265             2       471.30   0.00      0.5        0.00
# 112638           265             2       479.00   6.00      0.0        0.00
# 135263           265             2       330.00   0.00      0.0        0.00
# 137659           265             2       308.20   0.00      0.0        0.00
# 147293           265             1       400.00   5.00      0.0       25.00
# 164754           230             2       450.00   0.00      0.0        0.00
# 238707           265             3       555.55   0.00      0.0        0.00
# 276145           265             1       350.00   5.00      0.0        0.00
# 284905           265             1       338.00   0.00      0.0        0.00
# 300448           265             2       438.40   1.00      0.0        0.00
# 312414           264             2       700.00   0.00      0.0        0.00
# 325364           265             1       385.00   1.75      0.0       40.00
# 326618           265             1       347.40   0.00      0.5       69.78
# 348204           265             2       528.70   0.00      0.5        0.00
# 365510           265             2       355.00   0.00      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 5522            6.94                    1.0        757.94
# 6461            6.94                    1.0        440.16
# 10742          34.75                    1.0        535.75
# 66884           0.00                    1.0        325.65
# 83735           0.00                    1.0        406.13
# 100970         22.30                    1.0        496.35
# 112638         19.30                    1.0        506.55
# 135263          6.55                    1.0        339.30
# 137659         12.75                    1.0        321.95
# 147293         35.30                    1.0        468.05
# 164754          0.00                    1.0        453.50
# 238707          0.00                    1.0        556.55
# 276145          0.00                    1.0        357.75
# 284905         19.69                    1.0        360.44
# 300448         12.75                    1.0        453.15
# 312414          6.94                    1.0        710.44
# 325364          9.10                    1.0        436.85
# 326618          0.00                    1.0        420.43
# 348204          0.00                    1.0        530.20
# 365510          0.00                    1.0        356.50
#
#         congestion_surcharge  Airport_Fees_Combined
# 5522                     0.0                   0.00
# 6461                     0.0                   1.75
# 10742                    0.0                   0.00
# 66884                    0.0                   1.25
# 83735                    0.0                   1.75
# 100970                   0.0                   1.25
# 112638                   0.0                   1.25
# 135263                   0.0                   1.75
# 137659                   0.0                   0.00
# 147293                   0.0                   1.75
# 164754                   2.5                   0.00
# 238707                   0.0                   0.00
# 276145                   0.0                   1.75
# 284905                   0.0                   1.75
# 300448                   0.0                   0.00
# 312414                   2.5                   0.00
# 325364                   0.0                   1.75
# 326618                   0.0                   1.75
# 348204                   0.0                   0.00
# 365510                   0.0                   0.00

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'Airport_Fees_Combined']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 372084 entries, 0 to 389999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               372084 non-null  int64
#  1   tpep_pickup_datetime   372084 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  372084 non-null  datetime64[us]
#  3   passenger_count        372084 non-null  float64
#  4   trip_distance          372084 non-null  float64
#  5   RatecodeID             372084 non-null  float64
#  6   store_and_fwd_flag     372084 non-null  object
#  7   PULocationID           372084 non-null  int64
#  8   DOLocationID           372084 non-null  int64
#  9   payment_type           372084 non-null  int64
#  10  fare_amount            372084 non-null  float64
#  11  extra                  372084 non-null  float64
#  12  mta_tax                372084 non-null  float64
#  13  tip_amount             372084 non-null  float64
#  14  tolls_amount           372084 non-null  float64
#  15  improvement_surcharge  372084 non-null  float64
#  16  total_amount           372084 non-null  float64
#  17  congestion_surcharge   372084 non-null  float64
#  18  Airport_Fees_Combined  372084 non-null  float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# memory usage: 56.8+ MB

# %%
def category_var(df):
    num_colm= df.select_dtypes(include=np.number).columns.tolist()
    cat_colm= df.select_dtypes(exclude=np.number).columns.tolist()
    return num_colm, cat_colm
num_colm, cat_colm = category_var(df)

print("Numerical Columns:", num_colm)
print("Categorical Columns:", cat_colm)
# Out:
# Numerical Columns: ['VendorID', 'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_Fees_Combined']
# Categorical Columns: ['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'store_and_fwd_flag']

# %%
sns.distplot(df['passenger_count'],kde=False)
plt.title('Distribution of Passenger Count')
plt.show()
# Out:
# <ipython-input-30-a5d4debf96bd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['passenger_count'],kde=False)

# %%
print(df['tpep_pickup_datetime'].nunique())
df['tpep_dropoff_datetime'].nunique()
# Out:
# 363702
# 363857

# %%
df['tpep_pickup_day']=df['tpep_pickup_datetime'].dt.day_name()
df['tpep_dropoff_day']=df['tpep_dropoff_datetime'].dt.day_name()
df['tpep_pickup_day'].value_counts()
df['tpep_dropoff_day'].value_counts()
# Out:
# tpep_dropoff_day
# Thursday     58273
# Wednesday    57104
# Friday       54963
# Tuesday      54414
# Saturday     53858
# Sunday       46863
# Monday       46609
# Name: count, dtype: int64

# %%
figure,ax=plt.subplots(nrows=2,ncols=1,figsize=(10,10))
sns.countplot(x='tpep_pickup_day',data=df,ax=ax[0])
ax[0].set_title('Number of Pickups done on each day of the week')
sns.countplot(x='tpep_dropoff_day',data=df,ax=ax[1])
ax[1].set_title('Number of dropoffs done on each day of the week')
plt.tight_layout()

# %%
# Delimit pickup_datetime variable
df['pickup_date'] = df['tpep_pickup_datetime'].dt.date # Extract date
df['pickup_time'] = df['tpep_pickup_datetime'].dt.time # Extract time
df['pickup_day_name']=df['tpep_pickup_datetime'].dt.day_name()
df['dropoff_day_name']=df['tpep_pickup_datetime'].dt.day_name()
df['dropoff_hour'] = df['tpep_dropoff_datetime'].dt.hour # Extract hour
# Delimit dropoff_datetime variables
df['dropoff_date'] = df['tpep_dropoff_datetime'].dt.date # Extract date
df['dropoff_time'] = df['tpep_dropoff_datetime'].dt.time # Extract time

# Additional pickup features
df['pickup_month'] = df['tpep_pickup_datetime'].dt.month # Extract month
# train_data['pickup_month'] = train_data.pickup_datetime.dt.to_period('M') # Extract yearmonth
#train_data['pickup_YYYYMM'] = train_data['pickup_datetime'].apply(lambda x: x.strftime('%Y%m')) # Extract yearmonth
df['pickup_hour'] = df['tpep_pickup_datetime'].dt.hour # Extract hour
df['pickup_weekday'] = czzzz# Extract day of week
df['dropoff_hour'] = df['tpep_dropoff_datetime'].dt.hour # Extract hour

# %%
figure,ax=plt.subplots(nrows=3,ncols=1,figsize=(10,10))
sns.countplot(x='pickup_month',data=df,ax=ax[0])
ax[0].set_title('Number of Pickups done on each day of the month')
sns.countplot(x='pickup_day_name',data=df,ax=ax[1])
ax[1].set_title('Number of Pickup done on each day of the week')
sns.countplot(x='dropoff_day_name',data=df,ax=ax[2])
ax[2].set_title('Number of dropoff done on each day of the week')

plt.tight_layout()

# %%
figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(20,5))

ax1.set_title('Pickup Days')
ax=sns.countplot(x="pickup_day_name",data=df,ax=ax1)

ax2.set_title('Dropoff Days')
ax=sns.countplot(x="dropoff_day_name",data=df,ax=ax2)

# %%
df['pickup_day_no']=df['tpep_pickup_datetime'].dt.weekday
df['dropoff_day_no']=df['tpep_dropoff_datetime'].dt.weekday

df['pickup_hour']=df['tpep_pickup_datetime'].dt.hour
df['dropoff_hour']=df['tpep_dropoff_datetime'].dt.hour

df['pickup_month']=df['tpep_pickup_datetime'].dt.month
df['dropoff_month']=df['tpep_dropoff_datetime'].dt.month

# %%
def time_of_day(x):
    if x in range(6,12):
        return 'Morning'
    elif x in range(12,16):
        return 'Afternoon'
    elif x in range(16,22):
        return 'Evening'
    else:
        return 'Late night'
df['pickup_timeofday']=df['pickup_hour'].apply(time_of_day)
df['dropoff_timeofday']=df['dropoff_hour'].apply(time_of_day)

# %%
figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(20,5))

ax1.set_title('Pickup time of day')
ax=sns.countplot(x="pickup_timeofday",data=df,ax=ax1)

ax2.set_title('Dropoff Datime of the day')
ax=sns.countplot(x="dropoff_timeofday",data=df,ax=ax2)

# %%
figure,(ax9,ax10)=plt.subplots(ncols=2,figsize=(20,5))

ax9.set_title('Pickup hour')
ax=sns.countplot(x="pickup_hour",data=df,ax=ax9)

ax10.set_title('Dropoff hour')
ax=sns.countplot(x="dropoff_hour",data=df,ax=ax10)

# %%
figure,(ax9,ax10)=plt.subplots(ncols=2,figsize=(20,5))

ax9.set_title('Pickup Days')
ax=sns.countplot(x="pickup_month",data=df,ax=ax9)

ax10.set_title('Dropoff Days')
ax=sns.countplot(x="dropoff_month",data=df,ax=ax10)

# %%
figure,(ax9,ax10)=plt.subplots(ncols=2,figsize=(20,5))

ax9.set_title('Pickup Days')
ax=sns.countplot(x="pickup_hour",data=df,ax=ax9)

ax10.set_title('Dropoff Days')
ax=sns.countplot(x="dropoff_hour",data=df,ax=ax10)

# %%
#visualization of relationship between distance and fare amount
plt.figure(figsize=(10,6))
sns.scatterplot(x='trip_distance', y='fare_amount', data= df)
plt.title('Relationship between Trip Distance and Trip Price')
plt.xlabel('Trip Distance (km)')
plt.ylabel('Fare Amount (USD)')
plt.show()

#calculate the correlation between distance and fare
correlation = df['trip_distance'].corr(df['fare_amount'])
print("Correlation between Trip Distance and Trip Price:", correlation)
# Out:
# Correlation between Trip Distance and Trip Price: 0.943845020970837

# %%
df['trip_distance'].value_counts(sort=True)
(df['trip_distance'] == 0).sum().sum()
df = df[df.trip_distance >0]
df['trip_distance'].value_counts()
df['trip_distance'].describe()
# Out:
# count    371429.000000
# mean          3.484111
# std           4.513981
# min           0.010000
# 25%           1.080000
# 50%           1.800000
# 75%           3.400000
# max          94.400000
# Name: trip_distance, dtype: float64

# %%
#visualization of relationship between distance and fare amount
plt.figure(figsize=(10,6))
sns.scatterplot(x='trip_distance', y='fare_amount', data= df)
plt.title('Relationship between Trip Distance and Trip Price')
plt.xlabel('Trip Distance (km)')
plt.ylabel('Fare Amount (USD)')
plt.show()

#calculate the correlation between distance and fare
correlation = df['trip_distance'].corr(df['fare_amount'])
print("Correlation between Trip Distance and Trip Price:", correlation)
# Out:
# Correlation between Trip Distance and Trip Price: 0.943845020970837

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371429 entries, 0 to 389999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               371429 non-null  int64
#  1   tpep_pickup_datetime   371429 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  371429 non-null  datetime64[us]
#  3   passenger_count        371429 non-null  float64
#  4   trip_distance          371429 non-null  float64
#  5   RatecodeID             371429 non-null  float64
#  6   store_and_fwd_flag     371429 non-null  object
#  7   PULocationID           371429 non-null  int64
#  8   DOLocationID           371429 non-null  int64
#  9   payment_type           371429 non-null  int64
#  10  fare_amount            371429 non-null  float64
#  11  extra                  371429 non-null  float64
#  12  mta_tax                371429 non-null  float64
#  13  tip_amount             371429 non-null  float64
#  14  tolls_amount           371429 non-null  float64
#  15  improvement_surcharge  371429 non-null  float64
#  16  total_amount           371429 non-null  float64
#  17  congestion_surcharge   371429 non-null  float64
#  18  Airport_Fees_Combined  371429 non-null  float64
#  19  trip_duration_minutes  371429 non-null  float64
#  20  pickup_day_no          371429 non-null  int32
#  21  dropoff_day_no         371429 non-null  int32
#  22  pickup_hour            371429 non-null  int32
#  23  dropoff_hour           371429 non-null  int32
#  24  pickup_month           371429 non-null  int32
#  25  dropoff_month          371429 non-null  int32
#  26  pickup_timeofday       371429 non-null  object
#  27  dropoff_timeofday      371429 non-null  object
# dtypes: datetime64[us](2), float64(13), int32(6), int64(4), object(3)
# memory usage: 73.7+ MB

# %%
grouped_data = df.groupby('pickup_month').agg({'total_amount': 'sum'}).plot()
grouped_data.set_xlabel('Month')
grouped_data.set_ylabel('Total Amount')
grouped_data.set_title('Total Amount by Month')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab
import geopandas as gpd
# Read file using gpd.read_file()
gdf = gpd.read_file('taxi_zones.shp')
gdf.plot()
gdf.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int32
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int32
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int32(2), object(2)
# memory usage: 12.5+ KB

# %%
merged_df = pd.merge(df, gdf, left_on='PULocationID', right_on='LocationID')
merged_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-09-30 01:39:21   2023-09-30 01:53:09              1.0
# 1         2  2023-09-02 04:10:38   2023-09-02 04:24:29              4.0
# 2         2  2023-09-11 07:21:33   2023-09-11 07:51:17              2.0
# 3         2  2023-09-28 18:24:58   2023-09-28 18:32:11              1.0
# 4         2  2023-09-30 23:48:50   2023-10-01 00:07:41              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.38         1.0                  N           246           162
# 1           4.37         1.0                  N           246           151
# 2          15.58         3.0                  N           161             1
# 3           1.24         1.0                  N           231           249
# 4           4.08         1.0                  N           113           263
#
#    payment_type  ...  dropoff_month  pickup_timeofday  dropoff_timeofday  \
# 0             1  ...              9        Late night         Late night
# 1             1  ...              9        Late night         Late night
# 2             1  ...              9           Morning            Morning
# 3             1  ...              9           Evening            Evening
# 4             1  ...             10        Late night         Late night
#
#    OBJECTID  Shape_Leng  Shape_Area                       zone  LocationID  \
# 0       246    0.069467    0.000281  West Chelsea/Hudson Yards         246
# 1       246    0.069467    0.000281  West Chelsea/Hudson Yards         246
# 2       161    0.035804    0.000072             Midtown Center         161
# 3       231    0.063420    0.000167       TriBeCa/Civic Center         231
# 4       113    0.032745    0.000058    Greenwich Village North         113
#
#      borough                                           geometry
# 0  Manhattan  POLYGON ((983031.177 217138.506, 983640.32 216...
# 1  Manhattan  POLYGON ((983031.177 217138.506, 983640.32 216...
# 2  Manhattan  POLYGON ((991081.026 214453.698, 990952.644 21...
# 3  Manhattan  POLYGON ((981667.364 203305, 981854.109 203130...
# 4  Manhattan  POLYGON ((986643.64 204346.324, 986592.535 204...
#
# [5 rows x 35 columns]

# %%
grouped_data = merged_df.groupby('PULocationID')
# Calculate the sum of 'PULocationID' for each category
sum_values = grouped_data['PULocationID'].sum()
#print("\nSum of values by category:\n", sum_values)
# Applying multiple aggregations
aggregated_data = grouped_data.agg({'PULocationID': ['mean', 'sum', 'count']})
#print("\nAggregated data:\n", aggregated_data)

# %%
merged_df['PULocationID'].info()
gdf['zone'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 368100 entries, 0 to 368099
# Series name: PULocationID
# Non-Null Count   Dtype
# --------------   -----
# 368100 non-null  int64
# dtypes: int64(1)
# memory usage: 2.8 MB
# <class 'pandas.core.series.Series'>
# RangeIndex: 263 entries, 0 to 262
# Series name: zone
# Non-Null Count  Dtype
# --------------  -----
# 263 non-null    object
# dtypes: object(1)
# memory usage: 2.2+ KB

# %%
grouped_data = merged_df.groupby(['zone','pickup_hour']).agg({'pickup_hour ':sum})
grouped_data = merged_df.apply(lambda x: x.sort_values(ascending=False).head(3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-360-5ad5906deaba> in <cell line: 0>()
# ----> 1 grouped_data = merged_df.groupby(['zone','pickup_hour']).agg({'pickup_hour ':sum})
#       2 grouped_data = merged_df.apply(lambda x: x.sort_values(ascending=False).head(3))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1430
#    1431         op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432         result = op.agg()
#    1433         if not is_dict_like(func) and result is not None:
#    1434             # GH #52849
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg(self)
#     188
#     189         if is_dict_like(func):
# --> 190             return self.agg_dict_like()
#     191         elif is_list_like(func):
#     192             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     421         Result of aggregation.
#     422         """
# --> 423         return self.agg_or_apply_dict_like(op_name="agg")
#     424
#     425     def compute_dict_like(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg_or_apply_dict_like(self, op_name)
#    1606             obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607         ):
# -> 1608             result_index, result_data = self.compute_dict_like(
#    1609                 op_name, selected_obj, selection, kwargs
#    1610             )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460         is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461         func = cast(AggFuncTypeDict, self.func)
# --> 462         func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     463
#     464         is_non_unique_col = (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     661             cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662             if len(cols) > 0:
# --> 663                 raise KeyError(f"Column(s) {list(cols)} do not exist")
#     664
#     665         aggregator_types = (list, tuple, dict)
#
# KeyError: "Column(s) ['pickup_hour '] do not exist"

# %%
gdf['zone'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 263 entries, 0 to 262
# Series name: zone
# Non-Null Count  Dtype
# --------------  -----
# 263 non-null    object
# dtypes: object(1)
# memory usage: 2.2+ KB

# %%
# Calculate the difference in minutes and store it in a new column
merged_df['trip_duration_minutes'] = (merged_df['tpep_dropoff_datetime'] - merged_df['tpep_pickup_datetime']).dt.total_seconds() / 60

# %%
merged_df.info()
merged_df['trip_distance'].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371429 entries, 0 to 389999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               371429 non-null  int64
#  1   tpep_pickup_datetime   371429 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  371429 non-null  datetime64[us]
#  3   passenger_count        371429 non-null  float64
#  4   trip_distance          371429 non-null  float64
#  5   RatecodeID             371429 non-null  float64
#  6   store_and_fwd_flag     371429 non-null  object
#  7   PULocationID           371429 non-null  int64
#  8   DOLocationID           371429 non-null  int64
#  9   payment_type           371429 non-null  int64
#  10  fare_amount            371429 non-null  float64
#  11  extra                  371429 non-null  float64
#  12  mta_tax                371429 non-null  float64
#  13  tip_amount             371429 non-null  float64
#  14  tolls_amount           371429 non-null  float64
#  15  improvement_surcharge  371429 non-null  float64
#  16  total_amount           371429 non-null  float64
#  17  congestion_surcharge   371429 non-null  float64
#  18  Airport_Fees_Combined  371429 non-null  float64
#  19  trip_duration_minutes  371429 non-null  float64
#  20  pickup_day_no          371429 non-null  int32
#  21  dropoff_day_no         371429 non-null  int32
#  22  pickup_hour            371429 non-null  int32
#  23  dropoff_hour           371429 non-null  int32
#  24  pickup_month           371429 non-null  int32
#  25  dropoff_month          371429 non-null  int32
#  26  pickup_timeofday       371429 non-null  object
#  27  dropoff_timeofday      371429 non-null  object
# dtypes: datetime64[us](2), float64(13), int32(6), int64(4), object(3)
# memory usage: 81.7+ MB
# count    371429.000000
# mean          3.484111
# std           4.513981
# min           0.010000
# 25%           1.080000
# 50%           1.800000
# 75%           3.400000
# max          94.400000
# Name: trip_distance, dtype: float64

# %%
merged_df['trip_duration_minutes'].max()
# Out:
# 99.98333333333333

# %%
merged_df['trip_duration_minutes'].value_counts(sort=True)
(merged_df['trip_duration_minutes'] == 0).sum().sum()
merged_df = df[df.trip_duration_minutes >0]
merged_df['trip_duration_minutes'].value_counts()
merged_df['trip_duration_minutes'].describe()
# Out:
# count    371429.000000
# mean         16.251740
# std           1.728720
# min          12.019479
# 25%          14.964605
# 50%          15.762744
# 75%          17.720478
# max          19.012393
# Name: trip_duration_minutes, dtype: float64

# %%
merged_df['trip_duration_minutes'].plot()
# Out:
# <Axes: >

# %%
grouped_data = merged_df.groupby('pickup_hour')
print(grouped_data)
aggregated_data = grouped_data.agg({'trip_distance': ['mean']})
print("\nAggregated data:\n", aggregated_data)
aggregated_data.plot()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ec5eb143090>
#
# Aggregated data:
#              trip_distance
#                      mean
# pickup_hour
# 0                3.942564
# 1                3.548222
# 2                3.259769
# 3                3.512976
# 4                5.102409
# 5                6.190835
# 6                4.941311
# 7                3.801672
# 8                3.296513
# 9                3.206981
# 10               3.205483
# 11               3.143036
# 12               3.217200
# 13               3.454506
# 14               3.621590
# 15               3.529400
# 16               3.541034
# 17               3.269867
# 18               2.987433
# 19               3.205621
# 20               3.544898
# 21               3.557559
# 22               3.869372
# 23               4.177787
# <Axes: xlabel='pickup_hour'>

# %%
grouped_data = merged_df.groupby('pickup_hour')
print(grouped_data)
aggregated_data = grouped_data.agg({'trip_duration_minutes': ['mean']})
print("\nAggregated data:\n", aggregated_data)
aggregated_data.plot(title="Pickup Hour vs trip duration in minutes")

plt.xlabel("Pickup Hour")
plt.ylabel("Trip Duration(min())")
plt.show()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ec5e71d7810>
#
# Aggregated data:
#              trip_duration_minutes
#                              mean
# pickup_hour
# 0                       14.062299
# 1                       12.838178
# 2                       12.019479
# 3                       12.036857
# 4                       13.982085
# 5                       15.314818
# 6                       14.875103
# 7                       15.107110
# 8                       15.508413
# 9                       15.713393
# 10                      16.129457
# 11                      16.617494
# 12                      16.918162
# 13                      17.580852
# 14                      18.860145
# 15                      19.012393
# 16                      18.953147
# 17                      17.720478
# 18                      15.762744
# 19                      14.964605
# 20                      14.768493
# 21                      14.461220
# 22                      15.118595
# 23                      15.293776

# %%
# Group by 'Category' and calculate the sum of 'Value'
import pandas as pd
grouped_data = merged_df.groupby('pickup_hour')
print(grouped_data)
aggregated_data = grouped_data.agg({'trip_duration_minutes': ['mean']})
trip_duration = aggregated_data.reset_index()
print(type(trip_duration))
print(trip_duration)
grouped_data = merged_df.groupby('pickup_hour')
print(grouped_data)
aggregated_data = grouped_data.agg({'trip_distance': ['mean']})
trip_dis = aggregated_data.reset_index()
print(type(trip_dis))
print(trip_dis)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ec5ec66ea90>
# <class 'pandas.core.frame.DataFrame'>
#    pickup_hour trip_duration_minutes
#                                 mean
# 0            0             14.062299
# 1            1             12.838178
# 2            2             12.019479
# 3            3             12.036857
# 4            4             13.982085
# 5            5             15.314818
# 6            6             14.875103
# 7            7             15.107110
# 8            8             15.508413
# 9            9             15.713393
# 10          10             16.129457
# 11          11             16.617494
# 12          12             16.918162
# 13          13             17.580852
# 14          14             18.860145
# 15          15             19.012393
# 16          16             18.953147
# 17          17             17.720478
# 18          18             15.762744
# 19          19             14.964605
# 20          20             14.768493
# 21          21             14.461220
# 22          22             15.118595
# 23          23             15.293776
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ec5f6acbf50>
# <class 'pandas.core.frame.DataFrame'>
#    pickup_hour trip_distance
#                         mean
# 0            0      3.942564
# 1            1      3.548222
# 2            2      3.259769
# 3            3      3.512976
# 4            4      5.102409
# 5            5      6.190835
# 6            6      4.941311
# 7            7      3.801672
# 8            8      3.296513
# 9            9      3.206981
# 10          10      3.205483
# 11          11      3.143036
# 12          12      3.217200
# 13          13      3.454506
# 14          14      3.621590
# 15          15      3.529400
# 16          16      3.541034
# 17          17      3.269867
# 18          18      2.987433
# 19          19      3.205621
# 20          20      3.544898
# 21          21      3.557559
# 22          22      3.869372
# 23          23      4.177787

# %%
trip_duration['speed']=trip_dis['trip_distance'].values/trip_duration['trip_duration_minutes'].values

# %%
trip_duration['speed'] = trip_duration['speed'].values*60

# %%
print(trip_duration)
# Out:
#    pickup_hour trip_duration_minutes      speed
#                                 mean
# 0            0             14.062299  16.821847
# 1            1             12.838178  16.582829
# 2            2             12.019479  16.272432
# 3            3             12.036857  17.511098
# 4            4             13.982085  21.895485
# 5            5             15.314818  24.254295
# 6            6             14.875103  19.931202
# 7            7             15.107110  15.098872
# 8            8             15.508413  12.753775
# 9            9             15.713393  12.245531
# 10          10             16.129457  11.924084
# 11          11             16.617494  11.348411
# 12          12             16.918162  11.409750
# 13          13             17.580852  11.789551
# 14          14             18.860145  11.521406
# 15          15             19.012393  11.138210
# 16          16             18.953147  11.209854
# 17          17             17.720478  11.071487
# 18          18             15.762744  11.371498
# 19          19             14.964605  12.852814
# 20          20             14.768493  14.401867
# 21          21             14.461220  14.760413
# 22          22             15.118595  15.356078
# 23          23             15.293776  16.390146

# %%
merged_df['zone'].info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zone'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-325-bec9635ae45a> in <cell line: 0>()
# ----> 1 merged_df['zone'].info()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'zone'

# %%
grouped_data = merged_df.groupby('pickup_hour')
print(grouped_data)
aggregated_data = grouped_data.agg({'trip_duration_minutes': ['mean']})
print("\nAggregated data:\n", aggregated_data)
aggregated_data.plot(title="Pickup Hour vs trip duration in minutes")

plt.xlabel("Pickup Hour")
plt.ylabel("Trip Duration(min())")
plt.show()

# %%
# Show relationship between tip and trip distance
plt.figure(figsize=(10,6))
sns.scatterplot(x='trip_distance', y='tip_amount', data= merged_df)
plt.title('Relationship between trip_distance  and tip_amount')
plt.xlabel('trip_distance')
plt.ylabel('tip_amount(USD)')
plt.show()

#calculate the correlation between distance and fare
correlation = df['trip_distance'].corr(df['tip_amount'])
print("Correlation between trip_distance and ftip_amount:", correlation)
# Out:
# Correlation between trip_distance and ftip_amount: 0.590339555852792

# %%
merged_df['payment_type'].value_counts()
merged_df['payment_type'].value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6d5d6680f10a> in <cell line: 0>()
# ----> 1 merged_df['payment_type'].value_counts()
#       2 merged_df['payment_type'].value_counts(normalize=True)
#
# NameError: name 'merged_df' is not defined

# %%
merged_df['pickup_day_name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d28c9f96029> in <cell line: 0>()
# ----> 1 merged_df['pickup_day_name'].value_counts()
#
# NameError: name 'merged_df' is not defined
